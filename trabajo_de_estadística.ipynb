# %% [markdown]
# <a href="https://colab.research.google.com/github/MaicolMA/trabajos-varios-/blob/main/trabajo_de_estad%C3%ADstica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# MAtriz de correlacion

# %%
#importar librerias
import pandas as pd
df= pd.read_csv("DAto.csv")
#visualizar el daataframe
df.head()
# Out:
#    NO.                     Time  Interval  Indoor Temperature(°C)  \
# 0    1  2019/01/01 1:24:53 a.m.        30                    22.6
# 1    2  2019/01/01 1:54:53 a.m.        30                    22.5
# 2    3  2019/01/01 2:24:53 a.m.        30                    22.4
# 3    4  2019/01/01 2:54:53 a.m.        30                    22.4
# 4    5  2019/01/01 3:24:53 a.m.        30                    22.2
#
#    Indoor Humidity(%)  Outdoor Temperature(°C)  Outdoor Humidity(%)  \
# 0                  51                     16.4                   64
# 1                  50                     16.3                   63
# 2                  49                     16.1                   63
# 3                  49                     16.4                   63
# 4                  49                     16.1                   64
#
#    Relative Pressure(hpa)  Absolute Pressure(hpa)  Wind Speed(km/h)  ...  \
# 0                  1008.2                   822.9               5.0  ...
# ...

# %%
#filtrar variiaables numericas
df_numerico= df.select_dtypes(include="number")
#generar estadistica del df_numerico
df_numerico.describe()
# Out:
#                NO.     Interval  Indoor Temperature(°C)  Indoor Humidity(%)  \
# count  7545.000000  7545.000000             7545.000000         7545.000000
# mean   3774.625182    30.038966               26.800583           66.425447
# std    2180.282831     1.154349               13.461716            6.552204
# min       1.000000    19.000000               19.900000           41.000000
# 25%    1887.000000    30.000000               22.100000           63.000000
# 50%    3773.000000    30.000000               23.200000           68.000000
# 75%    5663.000000    30.000000               24.800000           71.000000
# max    7555.000000    92.000000               84.700000           78.000000
#
#        Outdoor Temperature(°C)  Outdoor Humidity(%)  Relative Pressure(hpa)  \
# count              7545.000000          7545.000000             7545.000000
# mean                 22.797522            80.947117             1174.377005
# ...

# %%
#generar la matriz de corelación
matriz_correlacion= df_numerico.corr()
#imprimir la matriz de correlacion
matriz_correlacion
# Out:
#                               NO.  Interval  Indoor Temperature(°C)  \
# NO.                      1.000000 -0.018854                0.426079
# Interval                -0.018854  1.000000               -0.008144
# Indoor Temperature(°C)   0.426079 -0.008144                1.000000
# Indoor Humidity(%)      -0.179886  0.004538               -0.371333
# Outdoor Temperature(°C)  0.389209 -0.006483                0.980869
# Outdoor Humidity(%)      0.050004 -0.008597               -0.140490
# Relative Pressure(hpa)   0.427119 -0.008898                0.990708
# Absolute Pressure(hpa)  -0.416875  0.008522               -0.991233
# Wind Speed(km/h)        -0.029460 -0.006468                0.057717
# Gust(km/h)              -0.034320 -0.003389                0.062016
# DewPoint(°C)             0.419591 -0.008657                0.988899
# WindChill(°C)            0.389880 -0.006326                0.981405
# Hour Rainfall(mm)       -0.000278 -0.005047               -0.042712
# ...

# %% [markdown]
# ejercicio 1

# %%
num= int(input("Digite el numero: "))
acumula= 1
vueltas= 1
sumar=2
while vueltas <num:
  acumula= acumula+sumar
  sumar=sumar+1
  vueltas= vueltas+1
print ("La suma de su numero es",acumula)

# %% [markdown]
# ejercicio 2

# %%
numero=int(input("ingrese su numero: "))
if numero>10:
  sm=1
  acumulador=1
  it=0
  while it<10:
    sm=sm*acumulador
    acumulador=acumulador+1
    it=it+1
  print("su numero es mayor que 10 y la multiplicaión de los 10 primeros numeros son: ",sm)
else:
  sm=0
  acumulador=0
  while acumulador<=numero:
    sm=sm+acumulador
    acumulador=acumulador+1
  print("su numero no es menor que 10 y la suma de sus numeros es de: ",sm)

# %% [markdown]
# ejercicio 3

# %%
num= int(input("Digite el numero: "))
acumula= 1
multiplo3=0
while acumula <num:
  multiplo= acumula%3
  if multiplo==0:
    print (acumula," Es un numero multiplo de 3")
  acumula=acumula+1

# %% [markdown]
# ejercico 4

# %%
num= int(input("Digite el numero: "))
acumula= 1
multiplo5=0
while acumula <=num:
  multiplo= acumula%5
  if multiplo==0:
    print (acumula," Es un numero multiplo de 5")
  acumula=acumula+1

# %% [markdown]
# ejercicio 5

# %%
numt= int(input("Digite el numero: "))
aumen=1
suma2=0
suma1=0
while aumen<=numt:
  if aumen%2==0:
    convertN= aumen*-1
    suma1=suma1+convertN
  elif aumen%2!= 0:
    suma2=suma2+aumen
  aumen=aumen+1
print("la suma es: ",suma1+suma2)
# Out:
# Digite el numero: 8
# la suma es:  -4

# %% [markdown]
# ejercicio 6

# %%
num= int(input("Digite el primer numero: "))
num2= int(input("Digite el segundo  numero: "))
suma= 0
while num<=num2:
  if num%2==0:
    suma=suma+num
  num=num+1
print("la suma de los pares es",suma)

# %% [markdown]
# ejercicio 7

# %%
primo= int(input("digite el numero: "))
repetidor=0
contador=0
divisor=1
while repetidor <primo:
  if primo%divisor==0:
    contador=contador+1
  divisor=divisor+1
  repetidor=repetidor+1

if contador ==2:
  print(primo," Es un numero primo")
elif contador!=2:
  print(primo," No es un numero primo")

# %% [markdown]
# ejercicio 8

# %%
fact= int(input("Digite el numero: "))
sm=1
acumulador=1
it=0
while it<fact:
  sm=sm*acumulador
  acumulador=acumulador+1
  it=it+1
print("el factorial de",fact,"! es: ",sm)
# Out:
# Digite el numero: 6
# el factorial de 6 ! es:  720

# %% [markdown]
# ejercicio 9

# %%
fac= int(input("Digite el primer numero: "))
fac2=int(input("Digite el segundo numero: "))
sm=1
acumulador=1
it=0
sm2=1
acumulador2=1
it2=0
while it<fac:
  sm=sm*acumulador
  acumulador=acumulador+1
  it=it+1
while it2<fac2:
  sm2=sm2*acumulador2
  acumulador2=acumulador2+1
  it2=it2+1
print("la suma de sus factoriales es igual a: ",sm+sm2)

# %% [markdown]
# ejercicio 10

# %%
fibo=int(input("Digite el numero pra la serie Fibonacci: "))
m1=0
m2=1
while m2<fibo:
  m1=m1+m2
  m2=m1+m2
  print(m1,m2)
# Out:
# Digite el numero pra la serie Fibonacci: 13
# 1 2
# 3 5
# 8 13

# %% [markdown]
# ejercicio 11

# %%
num= int(input("Digite el numero N: "))
iter=1
suma= 0
contadora=1
while iter<num:
  if iter%2==0:
    suma=suma+num
    contadora=contadora+1
  iter=iter+1
print("la suma de los pares es",suma," y hay ", contadora,"numeros pares")

# %% [markdown]
# ejercicio 12

# %%
num= int(input("Digite el primer numero: "))
num2= int(input("Digite el segundo  numero: "))
suma= 0
contadora=0
while num<=num2:
  if num%2!=0:
    suma=suma+num
    contadora=contadora+1
  num=num+1
print("la suma de los inpares es",suma,"y hay ",contadora)
# Out:
# Digite el primer numero: 1
# Digite el segundo  numero: 5
# la suma de los inpares es 9 y hay  3
